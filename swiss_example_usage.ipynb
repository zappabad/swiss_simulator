# %% [markdown]
# # Constants

# %%
default_skill_value = 0 # value for a players skill if no player_skill is provided on player creation
skill_value_modifier = 0.05
total_of_decks = 8 # total amount of decks
player_num = 512 # total number of players in a tournament
num_rounds = 9 # total number of rounds in a tournament

# %% [markdown]
# # Player and Tournament Classes

# %%
import numpy as np
import pandas as pd
from threading import Lock

class Deck:
    def __init__(self, name):
        self.name = name
        self.matchup_spread = {}  # Dictionary to store win probabilities against other decks

    def set_matchup_win_prob(self, opponent_deck_name, win_prob):
        """Set the win probability against a specific opponent deck."""
        self.matchup_spread[opponent_deck_name] = win_prob

    def get_matchup_win_prob(self, opponent_deck_name):
        """Retrieve the win probability against a specific opponent deck."""
        return self.matchup_spread.get(opponent_deck_name, 0.5)  # Default to 0.5 if not set
    
    def __str__(self):
        return self.name

class DeckManager:
    def __init__(self):
        self.decks = {}

    def add_deck(self, deck):
        """Add a deck to the manager."""
        self.decks[deck.name] = deck

    def generate_win_probabilities(self, deck_names):
        """Generate win probabilities for decks."""
        num_decks = len(deck_names)
        for i in range(num_decks):
            for j in range(i + 1, num_decks):
                # Sample from a normal distribution with mean=0.5 and std=0.15
                win_prob = np.clip(np.random.normal(0.5, 0.15), 0, 1)
                
                self.decks[deck_names[i]].set_matchup_win_prob(deck_names[j], win_prob)
                self.decks[deck_names[j]].set_matchup_win_prob(deck_names[i], 1 - win_prob)

    def get_win_prob_matrix(self):
        """Retrieve the win probability matrix."""
        deck_names = list(self.decks.keys())
        num_decks = len(deck_names)
        matrix = np.zeros((num_decks, num_decks))
        
        for i in range(num_decks):
            for j in range(num_decks):
                matrix[i, j] = self.decks[deck_names[i]].get_matchup_win_prob(deck_names[j])
        
        return matrix

    def get_win_prob_dataframe(self):
        """Retrieve the win probability matrix as a DataFrame."""
        deck_names = list(self.decks.keys())
        num_decks = len(deck_names)
        matrix = np.zeros((num_decks, num_decks))
        
        for i in range(num_decks):
            for j in range(num_decks):
                matrix[i, j] = self.decks[deck_names[i]].get_matchup_win_prob(deck_names[j])
        
        # Convert to DataFrame for better visualization
        df = pd.DataFrame(matrix, index=deck_names, columns=deck_names)
        return df

class Player:
    def __init__(self, player_id, alias, player_skill=default_skill_value, deck=None):
        self.id = player_id
        self.alias = alias
        self.skill = player_skill
        self.deck = deck
        self.wins = 0
        self.losses = 0
        self.history = []  # List to store match results
        self.history_lock = Lock()
    
    def __reduce__(self):
        # The object's state is returned as a tuple:
        # (callable, arguments_to_callable, additional_state)
        # Lock object is not pickled, so we're not including it in the state.
        return (self.__class__, (self.id, self.alias, self.skill, self.deck), {'wins': self.wins, 'losses': self.losses, 'history': self.history})
    
    def __setstate__(self, state):
        self.wins = state.get('wins', 0)
        self.losses = state.get('losses', 0)
        self.history = state.get('history', [])
        self.history_lock = Lock()  # Initialize a new Lock object after unpickling

    def set_deck(self, deck):
        """Set the deck for the player."""
        self.deck = deck

    def get_deck(self):
        """Retrieve the player's deck."""
        return self.deck

    def record_match(self, tournament, tournament_round, opponent, result):
        with self.history_lock:
            self.history.append([tournament.name, tournament_round, str(opponent.id) + opponent.alias, result])
            
    def get_tournament_history(self, tournament):
        tournament_results = [history for history in self.history if history[0] == tournament.name]
        return tournament_results

    def get_tournament_standing(self, tournament):
        tournament_results = [history for history in self.history if history[0] == tournament.name]
        wins = 0
        losses = 0
        for match in tournament_results:
            result = match[-1]
            if result == "W":
                wins += 1
            elif result == "L":
                losses += 1
        return (wins, losses)

    def __str__(self):
        return f"[{self.id}] {self.alias} ({self.get_deck().name}) - Skill Level: {self.skill}"

    def __repr__(self):
        return f"[{self.id}] {self.alias} ({self.get_deck().name}) - Skill Level: {self.skill}"


class Tournament:
    def __init__(self, name, player_aliases, win_prob_matrix):
        self.name = name
        self.players = player_aliases
        self.win_prob_matrix = win_prob_matrix
        self.rounds_played = 0

    def __reduce__(self):
        # Assuming win_prob_matrix is a numpy array, which is pickleable.
        # players list is also assumed to be pickleable.
        return (self.__class__, (self.name, self.players, self.win_prob_matrix), {'rounds_played': self.rounds_played})

    def __setstate__(self, state):
        self.rounds_played = state.get('rounds_played', 0)

    def swiss_pairings(self):
        sorted_players = sorted(self.players, key=lambda x: x.get_tournament_standing(self)[0], reverse=True) # [0] is the wins side of the (wins, losses) tuple returned by get_tournament_standing
        pairings = []
        while sorted_players:
            p1 = sorted_players.pop(0)
            p2 = sorted_players.pop(0)
            pairings.append((p1, p2))
        return pairings

    def simulate_round(self):
        pairings = self.swiss_pairings()
        self.rounds_played += 1
        for p1, p2 in pairings:
            index_A = self.players.index(p1)
            index_B = self.players.index(p2)
            r = np.random.rand()
            if r < self.win_prob_matrix[index_A, index_B]:
                p1.record_match(self, self.rounds_played, p2, 'W')
                p2.record_match(self, self.rounds_played, p1, 'L')
            else:
                p1.record_match(self, self.rounds_played, p2, 'L')
                p2.record_match(self, self.rounds_played, p1, 'W')
        

    def simulate_tournament(self, num_rounds):
        for _ in range(num_rounds):
            self.simulate_round()

    def display_results(self):
        for player in self.players:
            print(f"{player.alias}: {player.get_tournament_history(self)}")
    
    def display_standings(self):
        for player in self.players:
            wins, losses = player.get_tournament_standing(self)
            print(f"{player}: {wins}-{losses}")
    
    def get_top_n(self, n):
        sorted_players = sorted(self.players, key=lambda player: player.get_tournament_standing(self)[0], reverse=True)
        return sorted_players[:n]
    
    def get_win_prob_dataframe(self):
        """Retrieve the win probability for each player matrix as a DataFrame."""
        player_names = [str(player.id) + player.alias for player in self.players]
        
        # Convert to DataFrame for better visualization
        df = pd.DataFrame(self.win_prob_matrix, index=player_names, columns=player_names)
        return df
    
    def __str__(self):
        return f"{self.name}"

    def __repr__(self):
        return f"{self.name}"

# %% [markdown]
# # Example Setup

# %%
from names import get_first_name
from random import sample, choice

# 1. Generate 4 decks and their matchup spreads.
deck_names = ["Bravo", "Iyslander", "Dromai", "Katsu", "Rhinar", "Fai", "Boltyn", "Azalea"]
deck_manager = DeckManager()

for name in deck_names:
    deck = Deck(name)
    deck_manager.add_deck(deck)

deck_manager.generate_win_probabilities(deck_names)

# 2. Create `player_num` players with generic names.
players = []
for i in range(player_num):
    players.append(Player(i, get_first_name()))

# 3. Sample the `skill_level` for each player.
skill_levels = np.random.normal(0, 1, player_num)
for i, player in enumerate(players):
    player.skill = skill_levels[i]

# 4. Assign a deck to each player.
available_decks = [choice(list(deck_manager.decks.values())) for _ in range(player_num)]

for i, player in enumerate(players):
    player.set_deck(available_decks[i])

# 5. Generate the `win_prob_matrix`.
tournament_win_prob_matrix = np.zeros((player_num, player_num))
for i in range(player_num):
    for j in range(player_num):
        if i != j:
            deck_win_prob = players[i].get_deck().get_matchup_win_prob(players[j].get_deck().name)
            skill_adjustment = skill_value_modifier * (players[i].skill - players[j].skill)
            tournament_win_prob_matrix[i, j] = deck_win_prob + skill_adjustment
            tournament_win_prob_matrix[j, i] = 1 - tournament_win_prob_matrix[i, j]

# %% [markdown]
# # Example usage

# %%
print("Matchup spread for each deck:")
print(deck_manager.get_win_prob_dataframe())

print('\n\nPlayers in the tournament:')
for i in range(0, player_num):
    print(players[i])
# Out:
# Matchup spread for each deck:
#               Bravo  Iyslander    Dromai     Katsu    Rhinar       Fai  \
# Bravo      0.500000   0.494067  0.593187  0.464889  0.510416  0.665559
# Iyslander  0.505933   0.500000  0.667457  0.548241  0.688812  0.477281
# Dromai     0.406813   0.332543  0.500000  0.467226  0.091635  0.639457
# Katsu      0.535111   0.451759  0.532774  0.500000  0.275651  0.371318
# Rhinar     0.489584   0.311188  0.908365  0.724349  0.500000  0.449507
# Fai        0.334441   0.522719  0.360543  0.628682  0.550493  0.500000
# Boltyn     0.487879   0.565619  0.367084  0.640990  0.615647  0.364614
# Azalea     0.716434   0.424288  0.612224  0.805467  0.484379  0.592139
#
#              Boltyn    Azalea
# Bravo      0.512121  0.283566
# Iyslander  0.434381  0.575712
# Dromai     0.632916  0.387776
# Katsu      0.359010  0.194533
# Rhinar     0.384353  0.515621
# Fai        0.635386  0.407861
# Boltyn     0.500000  0.670414
# Azalea     0.329586  0.500000
#
#
# Players in the tournament:
# Aiko (Azalea) - Skill Level: 1.2142178656850413
# Stacy (Azalea) - Skill Level: -1.2032486919109469
# Casey (Rhinar) - Skill Level: -0.579565952611982
# Chastity (Azalea) - Skill Level: -0.49827447378950707
# Robbie (Katsu) - Skill Level: 0.16653017553799956
# Angel (Katsu) - Skill Level: 0.3401524777001037
# Edward (Bravo) - Skill Level: -0.5097107709076787
# Bernice (Katsu) - Skill Level: 0.7180935060471197
# Patricia (Dromai) - Skill Level: -0.14896145044912654
# Naomi (Dromai) - Skill Level: 0.8329617455153144
# Robert (Katsu) - Skill Level: 1.6424828356079653
# David (Boltyn) - Skill Level: 0.5738348180707907
# Conrad (Dromai) - Skill Level: 1.1444073618887027
# Erica (Azalea) - Skill Level: 0.4042251492236922
# Jose (Azalea) - Skill Level: -1.0095556045166927
# Effie (Boltyn) - Skill Level: -0.24986072377235644
# Richard (Katsu) - Skill Level: 0.9688931735785918
# Frances (Boltyn) - Skill Level: 1.4293056227801801
# Janelle (Azalea) - Skill Level: 1.2274952297880064
# Lori (Boltyn) - Skill Level: 0.46994966731934107
# Howard (Dromai) - Skill Level: 0.20278193513362483
# Linda (Boltyn) - Skill Level: 1.1479299158997587
# Jorge (Bravo) - Skill Level: -0.9527030343007307
# Kacie (Dromai) - Skill Level: -0.29104251141805554
# Eddie (Dromai) - Skill Level: 2.502985897965107
# Sharon (Fai) - Skill Level: 0.12358321999939154
# Willie (Bravo) - Skill Level: -2.9792344796452825
# Wendy (Iyslander) - Skill Level: 0.34561244668207225
# Jerry (Iyslander) - Skill Level: -0.9482301773753281
# Howard (Dromai) - Skill Level: 0.6258419234008664
# Vivian (Iyslander) - Skill Level: -1.0733003262848353
# Debra (Katsu) - Skill Level: -0.446967754707559
# James (Azalea) - Skill Level: 0.8040070351870443
# Moses (Iyslander) - Skill Level: -1.0602256022457948
# Herman (Dromai) - Skill Level: 0.3757389021879931
# Susie (Iyslander) - Skill Level: -0.7565497466301534
# Natalie (Bravo) - Skill Level: -0.4375857716867294
# Mark (Dromai) - Skill Level: -0.6083349863718066
# Joe (Fai) - Skill Level: -0.2682902523976098
# Charles (Iyslander) - Skill Level: 1.2992535695425556
# Freeda (Bravo) - Skill Level: 0.6057400129116038
# Bruce (Katsu) - Skill Level: -1.0597462533892648
# James (Bravo) - Skill Level: 0.07307992736632928
# Tamar (Boltyn) - Skill Level: -1.3422121481203713
# Stephen (Iyslander) - Skill Level: -0.5543416652548648
# Bessie (Dromai) - Skill Level: 0.08037186396338492
# Rickey (Dromai) - Skill Level: 0.7995573165402692
# Kim (Fai) - Skill Level: -1.8071747288366087
# Johnnie (Dromai) - Skill Level: -0.0684977876196484
# Lisa (Boltyn) - Skill Level: 1.215147122346468
# Heather (Iyslander) - Skill Level: 0.3822255158016898
# David (Fai) - Skill Level: -0.297050816463449
# Elaine (Iyslander) - Skill Level: 0.3606758732872657
# Kirk (Rhinar) - Skill Level: -1.0686361591549185
# Doris (Boltyn) - Skill Level: -0.8125072730081355
# Patrick (Iyslander) - Skill Level: 1.1819887176845345
# Rene (Azalea) - Skill Level: 1.4294284688180379
# Raymond (Katsu) - Skill Level: 1.405431539090294
# Steven (Katsu) - Skill Level: -0.025474703920804923
# Frank (Rhinar) - Skill Level: -0.6701601950484396
# Kimberly (Rhinar) - Skill Level: 0.19664700184784362
# Tyrone (Bravo) - Skill Level: -0.35859982201905644
# Jeannie (Fai) - Skill Level: 0.709630734275652
# Gloria (Rhinar) - Skill Level: -1.3391559776903208
# Evan (Dromai) - Skill Level: 0.6062150738779982
# Everett (Iyslander) - Skill Level: 1.0891641723575423
# Nicholas (Iyslander) - Skill Level: -0.8441443726994944
# Deon (Iyslander) - Skill Level: 1.8365874743867414
# Britney (Boltyn) - Skill Level: 0.6111698741330147
# Michael (Azalea) - Skill Level: 0.724053484835705
# Ronald (Azalea) - Skill Level: -1.1042090565230707
# David (Boltyn) - Skill Level: -0.0710844258802548
# Michael (Iyslander) - Skill Level: 1.5621927503030038
# Oscar (Fai) - Skill Level: -0.5687830185785668
# Jack (Azalea) - Skill Level: -0.6405493391616054
# Richard (Fai) - Skill Level: -0.3827278134610091
# Shawn (Dromai) - Skill Level: -0.7551620732467433
# Edward (Rhinar) - Skill Level: 0.9517607201603181
# Gregory (Azalea) - Skill Level: 0.9609194077791918
# Ronald (Azalea) - Skill Level: -2.239437890226129
# John (Fai) - Skill Level: 1.3173376447793248
# Danielle (Fai) - Skill Level: 0.903609478944508
# Jimmy (Rhinar) - Skill Level: -1.1856716044972646
# Julie (Bravo) - Skill Level: -1.3824789588094237
# Melanie (Katsu) - Skill Level: 0.7731655852948366
# Angela (Azalea) - Skill Level: -0.16127032639045807
# Amy (Boltyn) - Skill Level: -0.34130570534773647
# Roxie (Katsu) - Skill Level: -1.2541569302369397
# Roy (Katsu) - Skill Level: 0.13526979312091164
# Rafael (Fai) - Skill Level: -0.43357129546475565
# Michell (Azalea) - Skill Level: -0.7779782152196767
# Christopher (Dromai) - Skill Level: -0.8694502690966989
# Gregory (Katsu) - Skill Level: 1.1955717950635274
# Antonia (Rhinar) - Skill Level: 0.5221530980364808
# Judy (Azalea) - Skill Level: 0.17617116290526388
# Annette (Bravo) - Skill Level: 1.0939095304706425
# Juan (Azalea) - Skill Level: 0.059741383603266474
# Alice (Fai) - Skill Level: 1.4938656646709196
# Jennifer (Fai) - Skill Level: -0.030969471619303048
# Myrtle (Rhinar) - Skill Level: 0.2303336768617587
# Andrew (Boltyn) - Skill Level: 0.6911463323547458
# Christopher (Boltyn) - Skill Level: 1.1268590185494431
# Keith (Iyslander) - Skill Level: -1.5143610042031106
# Rachel (Rhinar) - Skill Level: 0.20688409365719118
# Vernon (Fai) - Skill Level: 0.2722444910157544
# Lorraine (Dromai) - Skill Level: 2.3075506890029884
# Jeffrey (Iyslander) - Skill Level: -0.990626290335125
# Audrey (Boltyn) - Skill Level: -0.8625798990030238
# Verna (Azalea) - Skill Level: 0.385446028391928
# Eunice (Katsu) - Skill Level: -0.9567390282985101
# Yang (Katsu) - Skill Level: -0.4058668934142006
# Mary (Boltyn) - Skill Level: -2.0085355191086167
# Wilson (Rhinar) - Skill Level: 0.3538758908649126
# Angelo (Bravo) - Skill Level: 0.5554222977666274
# Barbara (Fai) - Skill Level: 0.958884044079317
# Kathleen (Bravo) - Skill Level: 0.3041202064200789
# Andy (Azalea) - Skill Level: 0.18502370041565028
# Crystal (Azalea) - Skill Level: -0.583821192610753
# Kelly (Fai) - Skill Level: 0.675771884924362
# Douglas (Bravo) - Skill Level: -1.0787679034811364
# Garrett (Rhinar) - Skill Level: -1.3053625271975782
# Georgia (Fai) - Skill Level: 0.5959044656060845
# Marlon (Rhinar) - Skill Level: -0.43523382039656844
# Virginia (Katsu) - Skill Level: -1.9306925794084369
# Mary (Azalea) - Skill Level: -0.8483014336494304
# James (Azalea) - Skill Level: 2.31741998366674
# Helen (Bravo) - Skill Level: 0.3147232046477048
# Lee (Boltyn) - Skill Level: 0.14900318453980024
# Devin (Bravo) - Skill Level: 0.8690255192754268
# Victor (Boltyn) - Skill Level: -0.19339402891885857
# Penny (Boltyn) - Skill Level: 0.3649563760814833
# Dennis (Katsu) - Skill Level: -0.3338334741235713
# Emily (Boltyn) - Skill Level: 0.2947441557942703
# Odell (Dromai) - Skill Level: -1.6780728974692152
# David (Azalea) - Skill Level: 0.1154415056169152
# Ashley (Dromai) - Skill Level: -0.1514411300980942
# Leo (Katsu) - Skill Level: 0.16313362689851754
# Franklin (Iyslander) - Skill Level: 0.05867253264469757
# Elma (Katsu) - Skill Level: 0.040870095580673636
# Deborah (Iyslander) - Skill Level: 1.4857338918399043
# Bradley (Katsu) - Skill Level: -1.0981176240233568
# Pedro (Iyslander) - Skill Level: 1.6558496142661583
# Robert (Azalea) - Skill Level: 0.20012830835481754
# Claudia (Katsu) - Skill Level: 0.776090239903995
# John (Azalea) - Skill Level: -0.7938414616753169
# Robert (Iyslander) - Skill Level: 0.6836586152403529
# Angela (Fai) - Skill Level: -1.1630735646706158
# Shirley (Bravo) - Skill Level: 0.19632583992355082
# Demetria (Rhinar) - Skill Level: -0.47031867498347213
# Marcelino (Dromai) - Skill Level: -0.3402518994869077
# Barbara (Fai) - Skill Level: 1.5387426048683603
# Robin (Dromai) - Skill Level: -0.5853155518377542
# Madeline (Boltyn) - Skill Level: 1.1064093704410944
# Mable (Dromai) - Skill Level: -0.12845456643757272
# Michael (Katsu) - Skill Level: 0.7846971624759024
# Shirley (Fai) - Skill Level: 0.23842680805617608
# Rosa (Dromai) - Skill Level: -2.163924214818876
# Brenda (Boltyn) - Skill Level: -0.6140071165582435
# Jacquelyn (Dromai) - Skill Level: 0.17934359228573676
# Elizabeth (Dromai) - Skill Level: 0.09360488663478356
# Roxann (Dromai) - Skill Level: -0.715926818047584
# Travis (Rhinar) - Skill Level: -0.15019397829745415
# Jose (Bravo) - Skill Level: 0.187797919197796
# Kevin (Fai) - Skill Level: 0.8966945816219475
# Nancy (Iyslander) - Skill Level: -1.5048272461847854
# Maryann (Dromai) - Skill Level: -0.8796316067561292
# Brian (Boltyn) - Skill Level: -1.152560204730575
# Raymond (Bravo) - Skill Level: 1.6572372084762508
# Melissa (Azalea) - Skill Level: 1.286258358817299
# Joseph (Katsu) - Skill Level: 0.505944912503578
# Jesus (Katsu) - Skill Level: 0.27935912106629734
# Ruth (Fai) - Skill Level: -0.4482051697514957
# Richard (Dromai) - Skill Level: -1.0029402052556848
# Eunice (Bravo) - Skill Level: -0.21829364604630755
# Juan (Dromai) - Skill Level: -0.03108487479338509
# Michael (Bravo) - Skill Level: -0.16896411602284298
# Angela (Boltyn) - Skill Level: -1.165220707786745
# Doris (Iyslander) - Skill Level: -1.339806187011535
# Patrick (Fai) - Skill Level: -0.665522364572352
# Wilbur (Iyslander) - Skill Level: 0.21097964744177627
# Deborah (Bravo) - Skill Level: -0.47094399011913884
# Adam (Bravo) - Skill Level: 0.6547322191317763
# Roy (Bravo) - Skill Level: 0.9408858372302746
# Eloise (Fai) - Skill Level: -1.1950494767665458
# Debbie (Iyslander) - Skill Level: -2.1555534459796033
# Richard (Dromai) - Skill Level: 1.0901751877095822
# Jo (Azalea) - Skill Level: 0.413722202178595
# Terry (Bravo) - Skill Level: -2.6080759652372127
# Maria (Katsu) - Skill Level: -1.342996366426511
# Ricky (Iyslander) - Skill Level: 0.6290374738689952
# Young (Rhinar) - Skill Level: 0.5150060062366609
# Dale (Boltyn) - Skill Level: 0.6049880567657523
# Joseph (Rhinar) - Skill Level: 0.7258160778196765
# Lisa (Fai) - Skill Level: -0.7331118489700487
# Kellie (Bravo) - Skill Level: -0.041156525384055516
# Steve (Boltyn) - Skill Level: 0.7928697476088071
# Susan (Bravo) - Skill Level: 1.7934391198397155
# Sadie (Dromai) - Skill Level: 1.4828893912506151
# Linda (Azalea) - Skill Level: -1.358653137681094
# Charlotte (Iyslander) - Skill Level: 1.0802070190447532
# Alma (Boltyn) - Skill Level: 0.08250772750754796
# Gregory (Rhinar) - Skill Level: -1.2530458362202088
# Victor (Fai) - Skill Level: -0.9983060111019466
# Edwin (Iyslander) - Skill Level: -0.13451785037452835
# Thomas (Dromai) - Skill Level: 1.766868032507772
# Darrell (Azalea) - Skill Level: -0.006341292574158143
# John (Rhinar) - Skill Level: 1.0405608573666922
# Randall (Boltyn) - Skill Level: -1.0051546043291597
# Albert (Katsu) - Skill Level: 0.9095593086092297
# Clifford (Azalea) - Skill Level: -0.5736551353087985
# Arthur (Azalea) - Skill Level: 0.9891222165757989
# Eddie (Bravo) - Skill Level: 1.2688907842076316
# Justin (Iyslander) - Skill Level: 0.46380561280912375
# Greta (Fai) - Skill Level: -0.015607399527975286
# Robert (Fai) - Skill Level: -0.48375446556678053
# Amanda (Fai) - Skill Level: 1.4102727348073085
# Lisa (Azalea) - Skill Level: 0.384826625442327
# Doug (Fai) - Skill Level: -0.12786939818397222
# Ida (Katsu) - Skill Level: 1.3280778700692022
# Heather (Fai) - Skill Level: -0.48433835397326
# Paul (Boltyn) - Skill Level: -0.08438547893144296
# Bernard (Dromai) - Skill Level: -0.27851410176313907
# Matthew (Katsu) - Skill Level: 0.799213608706765
# George (Rhinar) - Skill Level: 0.04078745468151056
# Cecil (Rhinar) - Skill Level: -0.982659278752301
# Pamelia (Rhinar) - Skill Level: 2.3876035850821586
# Myra (Dromai) - Skill Level: 1.0238081439892004
# Lowell (Boltyn) - Skill Level: 0.8791193636083802
# Sharon (Fai) - Skill Level: -1.3576511331730556
# Jamie (Fai) - Skill Level: 0.14982478696306648
# Nolan (Iyslander) - Skill Level: -0.3757609969711926
# Kenneth (Dromai) - Skill Level: -0.5975346037149706
# Marie (Rhinar) - Skill Level: 0.04936151066774365
# Donald (Bravo) - Skill Level: 0.0690242493704483
# Harriett (Dromai) - Skill Level: -0.7555301436330124
# Walter (Azalea) - Skill Level: -0.013217356209126124
# Jamie (Rhinar) - Skill Level: 1.0175424215467774
# Cheryl (Bravo) - Skill Level: -0.042400023036483186
# Hana (Dromai) - Skill Level: -0.8326157583265665
# Robert (Bravo) - Skill Level: -0.30460164970355624
# Jennifer (Bravo) - Skill Level: -0.30202473872843494
# Nellie (Azalea) - Skill Level: -1.0536201452780756
# Jean (Katsu) - Skill Level: 1.5905203634874145
# Ronald (Dromai) - Skill Level: 0.6521016001882716
# Cole (Azalea) - Skill Level: 0.9964650599506931
# Steven (Katsu) - Skill Level: -1.6713872532097873
# Ryan (Katsu) - Skill Level: -1.8014894743685703
# Benjamin (Fai) - Skill Level: 0.35970907083087333
# Daren (Boltyn) - Skill Level: 1.4488438517259392
# Ruth (Boltyn) - Skill Level: 0.4003966995629445
# Harold (Iyslander) - Skill Level: -0.5089233309854512
# Derrick (Azalea) - Skill Level: 0.5175201687620923
# Ryan (Bravo) - Skill Level: 0.4932588587179687
# Sean (Katsu) - Skill Level: -0.32653044346394006
# Reed (Dromai) - Skill Level: 0.20733192248328472
# Billy (Iyslander) - Skill Level: -0.7311565716434874
# Chad (Katsu) - Skill Level: 1.0217204346535096
# Beatrice (Boltyn) - Skill Level: -0.9803393801084681
# Willard (Katsu) - Skill Level: 0.6155265748729949
# Bobby (Azalea) - Skill Level: 1.961323919997691
# Kimberly (Rhinar) - Skill Level: -1.5431369027004849
# Josefa (Fai) - Skill Level: 1.1456952113576597
# Donald (Dromai) - Skill Level: -0.05649779962309504
# Steven (Iyslander) - Skill Level: 1.7974212645630427
# David (Boltyn) - Skill Level: 0.9230509324395638
# Lorraine (Rhinar) - Skill Level: 0.852499878929951
# Mark (Azalea) - Skill Level: 0.32779913663187643
# Maria (Fai) - Skill Level: -0.635660857812095
# Robert (Boltyn) - Skill Level: 0.26414711140264524
# Shannon (Bravo) - Skill Level: -0.36612943083493843
# David (Iyslander) - Skill Level: 0.1705456617831672
# Carmen (Fai) - Skill Level: -0.7123076774230945
# Mia (Iyslander) - Skill Level: -0.21340270049228094
# Pamela (Boltyn) - Skill Level: 1.477626431370764
# Kent (Boltyn) - Skill Level: 0.3577596211393132
# Gerald (Rhinar) - Skill Level: -0.6522663355272188
# Marva (Bravo) - Skill Level: -0.5053384293676972
# Daniel (Azalea) - Skill Level: 1.0919450036446072
# Ann (Dromai) - Skill Level: 1.6045212125106665
# Harold (Rhinar) - Skill Level: -0.4974447287620175
# John (Katsu) - Skill Level: 0.2840241574639642
# George (Boltyn) - Skill Level: 0.04029576506479535
# Stephen (Dromai) - Skill Level: 1.5795969882764496
# Lisa (Dromai) - Skill Level: -3.7459513959063813
# Katharine (Fai) - Skill Level: -1.075002820012819
# Jason (Bravo) - Skill Level: 1.3099640762635774
# Juanita (Azalea) - Skill Level: 1.1853644012039588
# Edgar (Iyslander) - Skill Level: -1.4116018247502289
# Larry (Boltyn) - Skill Level: 0.2402627939125883
# Barbara (Fai) - Skill Level: 0.43536104687757854
# Marcia (Katsu) - Skill Level: 2.045103681401655
# Samantha (Boltyn) - Skill Level: 2.284979650794653
# Glenn (Fai) - Skill Level: -0.7256525213802613
# Jolene (Fai) - Skill Level: -1.5775047802168054
# John (Katsu) - Skill Level: 0.3296858020941086
# Deborah (Katsu) - Skill Level: -0.8376500224803789
# Porter (Azalea) - Skill Level: -0.20330092668298302
# Dawn (Fai) - Skill Level: 0.2063760238445172
# Rita (Katsu) - Skill Level: 0.0037106060009218164
# Michael (Rhinar) - Skill Level: 0.057060265663927696
# Elissa (Dromai) - Skill Level: -0.821411667734859
# Karina (Fai) - Skill Level: 1.0916152182046954
# Richard (Bravo) - Skill Level: 0.00993468761649661
# Terry (Dromai) - Skill Level: -0.22847313810386466
# Jovita (Azalea) - Skill Level: 0.5565608817295329
# Tommie (Fai) - Skill Level: -0.010508708870192309
# Rick (Boltyn) - Skill Level: -1.0525034791974528
# James (Dromai) - Skill Level: 0.6064624812626181
# Jana (Dromai) - Skill Level: 0.5522702476129331
# Roy (Boltyn) - Skill Level: -0.5382444195520103
# Randal (Fai) - Skill Level: 1.4750865052975966
# Robert (Boltyn) - Skill Level: 0.8759470948445315
# Roseann (Azalea) - Skill Level: -0.26811306197706253
# Michael (Boltyn) - Skill Level: 0.5432145695337754
# Andrew (Boltyn) - Skill Level: 0.6746487108984581
# Michael (Katsu) - Skill Level: -1.0650594780116347
# Donald (Dromai) - Skill Level: -1.3358001622020153
# Helen (Azalea) - Skill Level: 0.7945796321681584
# Patricia (Fai) - Skill Level: 1.2964576480323127
# Richard (Rhinar) - Skill Level: 1.9055885031418818
# Jacob (Boltyn) - Skill Level: -0.3367886231748728
# Charleen (Azalea) - Skill Level: -0.48571246505617577
# Ann (Dromai) - Skill Level: -0.12817196929880406
# Edward (Iyslander) - Skill Level: 0.09769091931397547
# Jarrett (Boltyn) - Skill Level: 0.19450700762988915
# Jim (Iyslander) - Skill Level: 0.9700738606991498
# Keith (Bravo) - Skill Level: 1.0896212892998614
# Jefferson (Iyslander) - Skill Level: -0.16164978135398378
# Andrew (Katsu) - Skill Level: -1.2393933596422075
# Nancy (Dromai) - Skill Level: 1.6638180472421376
# Mark (Bravo) - Skill Level: -1.3042065917583863
# Jack (Fai) - Skill Level: 1.1900312947358749
# James (Iyslander) - Skill Level: 0.6435135110271158
# Angel (Boltyn) - Skill Level: 0.27683148242249633
# Kenneth (Bravo) - Skill Level: -0.31107942015495027
# Darrell (Dromai) - Skill Level: -0.89616279668141
# William (Katsu) - Skill Level: -1.3738456215690626
# Gary (Katsu) - Skill Level: 1.5870433009978349
# Justin (Boltyn) - Skill Level: 2.206701276547577
# Harold (Bravo) - Skill Level: 0.9333718784037498
# Greg (Rhinar) - Skill Level: -1.5629318152180054
# Kathleen (Azalea) - Skill Level: -0.0461154016950418
# Raymond (Boltyn) - Skill Level: 0.6448803255182487
# Andrew (Boltyn) - Skill Level: -0.07672565181378312
# Maragret (Rhinar) - Skill Level: 0.31264774022889086
# Ariana (Iyslander) - Skill Level: 1.0569423065074477
# Vaughn (Boltyn) - Skill Level: 0.41167516443929275
# Anna (Katsu) - Skill Level: -1.6909807454840655
# Patricia (Iyslander) - Skill Level: -0.3573978904749445
# Angel (Boltyn) - Skill Level: -0.48501774671712955
# Timothy (Bravo) - Skill Level: 0.7450050011156698
# Bryan (Boltyn) - Skill Level: -0.17420580944077388
# Norman (Fai) - Skill Level: 0.5875013170317894
# Catherine (Bravo) - Skill Level: 0.1935229414909029
# Stewart (Fai) - Skill Level: -0.9782316941393284
# Marilyn (Bravo) - Skill Level: -2.344570323560223
# Elizabeth (Fai) - Skill Level: 0.6187092914929648
# Gregory (Boltyn) - Skill Level: -0.7173803665842773
# Patricia (Rhinar) - Skill Level: -0.7965566196023324
# Michael (Azalea) - Skill Level: -0.08124850234489425
# Tonya (Boltyn) - Skill Level: -0.2722179504356286
# Sarah (Azalea) - Skill Level: 1.814125568236811
# William (Bravo) - Skill Level: 0.3426065720882243
# Melanie (Katsu) - Skill Level: -0.5435159039460955
# Bobby (Fai) - Skill Level: 2.5970707632933094
# Mirta (Fai) - Skill Level: 0.2891907437031532
# Kimberly (Boltyn) - Skill Level: -0.4374058791636337
# Charlotte (Rhinar) - Skill Level: 1.316390510485515
# Clara (Bravo) - Skill Level: -1.2094828305474425
# Wendell (Dromai) - Skill Level: -0.31815629740600787
# Jacqueline (Bravo) - Skill Level: -0.451984679447476
# Virginia (Boltyn) - Skill Level: 1.7854834686007277
# Peter (Azalea) - Skill Level: -0.5275105380391624
# Addie (Boltyn) - Skill Level: -0.12945667646437886
# Senaida (Dromai) - Skill Level: 2.3232863207242187
# Patrick (Iyslander) - Skill Level: 0.09456539333354175
# Andre (Dromai) - Skill Level: -0.6397689560199769
# Benjamin (Iyslander) - Skill Level: 1.0688487844369845
# Steven (Dromai) - Skill Level: 0.6409172159277104
# Nancy (Azalea) - Skill Level: -0.3906144119912167
# Raymond (Iyslander) - Skill Level: 0.879464354245777
# Marsha (Fai) - Skill Level: -0.004827544760742535
# Henry (Azalea) - Skill Level: 0.5494973678362864
# Kathleen (Dromai) - Skill Level: -0.22643399843473147
# Nancy (Bravo) - Skill Level: -1.6071949089155553
# Adrian (Bravo) - Skill Level: -1.2035212208326522
# Cathy (Boltyn) - Skill Level: 0.036542723279298146
# Jessie (Fai) - Skill Level: 1.6504448097479725
# Michael (Boltyn) - Skill Level: -0.09210530827472822
# John (Boltyn) - Skill Level: -0.41063280374517475
# Gilberto (Dromai) - Skill Level: -0.692273893856106
# Michael (Katsu) - Skill Level: -1.1393899905539413
# Katrina (Katsu) - Skill Level: -0.6434204445438326
# Jean (Boltyn) - Skill Level: 0.9732755132014782
# Betty (Iyslander) - Skill Level: 0.26330949012501664
# Matthew (Katsu) - Skill Level: -0.35389494784534686
# Dennis (Dromai) - Skill Level: -1.0341712127485032
# William (Rhinar) - Skill Level: -1.0789675611408376
# Delbert (Rhinar) - Skill Level: 0.777695068092707
# Georgene (Bravo) - Skill Level: 0.8563131354218692
# Patricia (Azalea) - Skill Level: -1.6944691492653425
# Brandi (Katsu) - Skill Level: 1.4442391148141047
# Gary (Boltyn) - Skill Level: -1.2360132436466236
# Sandra (Azalea) - Skill Level: 0.6416052875993552
# Patty (Boltyn) - Skill Level: 0.12290776805148161
# Christopher (Azalea) - Skill Level: -0.5010358225520865
# Esther (Boltyn) - Skill Level: 0.42452955518715263
# Robert (Rhinar) - Skill Level: 0.3552646801442998
# Danny (Bravo) - Skill Level: 0.6821355113079761
# Diane (Bravo) - Skill Level: 0.19006810844714958
# Donald (Iyslander) - Skill Level: 1.3930328052136292
# Casey (Bravo) - Skill Level: -1.0701461201082896
# Anna (Rhinar) - Skill Level: 0.29377918678308634
# Luke (Azalea) - Skill Level: -1.208537623130368
# Ann (Katsu) - Skill Level: -0.6370703658530241
# John (Iyslander) - Skill Level: -0.1840633128826172
# Tyrone (Katsu) - Skill Level: 0.377492570558351
# Gina (Dromai) - Skill Level: -1.2484265475807304
# Tony (Rhinar) - Skill Level: -0.43089848191371244
# Ruth (Iyslander) - Skill Level: -0.0827836051782705
# Dolores (Rhinar) - Skill Level: 0.2794788299401238
# Rita (Iyslander) - Skill Level: 1.3495046653722167
# James (Fai) - Skill Level: 1.6246473409551148
# Norma (Rhinar) - Skill Level: 0.1693181642739273
# Ronald (Dromai) - Skill Level: -1.8773605826713395
# Stacy (Boltyn) - Skill Level: -0.164338041169946
# Andre (Boltyn) - Skill Level: 0.5828957142598785
# Ida (Boltyn) - Skill Level: 0.6103975890581108
# Jennie (Bravo) - Skill Level: 0.3366447249848217
# Shannon (Rhinar) - Skill Level: -0.8027778315335563
# Dan (Bravo) - Skill Level: -1.4052890970243173
# Joann (Fai) - Skill Level: -0.2995476765807212
# Katherine (Dromai) - Skill Level: 0.71934852512328
# Mario (Boltyn) - Skill Level: 0.8245853134356278
# Kimberly (Katsu) - Skill Level: -0.8884476786413278
# Troy (Iyslander) - Skill Level: -0.8311373892580342
# Darren (Boltyn) - Skill Level: 1.1919152209764763
# Emily (Bravo) - Skill Level: 0.7929792779349765
# Gloria (Boltyn) - Skill Level: -0.20852169487629366
# Curtis (Dromai) - Skill Level: 0.300327710136815
# Shirley (Iyslander) - Skill Level: -1.224982036498259
# Clair (Dromai) - Skill Level: -0.8983031736307616
# Velma (Azalea) - Skill Level: 0.4847972392426053
# Ryan (Boltyn) - Skill Level: 0.40036325564988867
# David (Rhinar) - Skill Level: -1.1414398031153203
# Susan (Katsu) - Skill Level: -1.578542217887766
# Charles (Katsu) - Skill Level: -0.7450318799707915
# Anthony (Azalea) - Skill Level: 1.2196731169440451
# Jesse (Bravo) - Skill Level: -0.5475323739114022
# Loretta (Dromai) - Skill Level: -2.3126368555217462
# Roni (Katsu) - Skill Level: -0.21780085934730534
# Audrey (Iyslander) - Skill Level: -0.8486706515708915
# Lela (Rhinar) - Skill Level: -0.6368286694648507
# Ruth (Fai) - Skill Level: -0.8944649012865892
# Alice (Dromai) - Skill Level: -1.6015468906771575
# David (Fai) - Skill Level: 0.24376964805494206
# Bonnie (Azalea) - Skill Level: -0.26412451718997476
# Ruth (Bravo) - Skill Level: 1.1861287806148006
# Grace (Rhinar) - Skill Level: -0.9248151588600323
# Janet (Boltyn) - Skill Level: -0.153532297218586
# Margaret (Katsu) - Skill Level: -1.1011807550308061
# Damian (Katsu) - Skill Level: 1.4256824674137862
# Jacob (Azalea) - Skill Level: 1.162720834073776
# Martha (Rhinar) - Skill Level: 0.37226779435797996
# Sergio (Boltyn) - Skill Level: -2.0219511075759455
# Jane (Bravo) - Skill Level: -0.6212609558349894
# Frances (Azalea) - Skill Level: -0.10549096092326223
# Michael (Fai) - Skill Level: 0.7383391538761982
# Daniel (Dromai) - Skill Level: -0.4354905171100511
# Shirley (Boltyn) - Skill Level: 1.3119529550852944
# Joseph (Katsu) - Skill Level: 0.6984906113392706
# Sabrina (Katsu) - Skill Level: 0.7411952733072017
# Yolanda (Boltyn) - Skill Level: 1.0943139720354147
# Hazel (Azalea) - Skill Level: -0.38264284970429463
# Mark (Azalea) - Skill Level: 1.1513339095406494
# Sarah (Katsu) - Skill Level: -0.8969259135768105
# Kimberly (Azalea) - Skill Level: -0.08116797587676003
# Velvet (Boltyn) - Skill Level: -0.030679236043789228
# Barbara (Katsu) - Skill Level: 0.08850331106854617
# Elizabeth (Boltyn) - Skill Level: -0.27779004778942085
# Ronald (Katsu) - Skill Level: 1.8428444137808526
# Thomas (Rhinar) - Skill Level: -0.8388392275385567
# Michael (Bravo) - Skill Level: -0.2489938652458169
# Samuel (Fai) - Skill Level: -1.4134364932651022
# Gisele (Dromai) - Skill Level: 0.6733659267739048
# Jaqueline (Rhinar) - Skill Level: 0.1441684501560225
# Adriana (Bravo) - Skill Level: 1.0799416553378989
# Alfred (Iyslander) - Skill Level: 0.7876374665400067
# David (Bravo) - Skill Level: 0.10499368481109726
# Dave (Fai) - Skill Level: 0.3589293495659643
# Brenda (Rhinar) - Skill Level: -0.4561720243149384
# Junie (Boltyn) - Skill Level: -0.16167294075955185
# James (Boltyn) - Skill Level: 0.2016565433473158
# Elizabeth (Azalea) - Skill Level: -0.5574097098492177
# Carlos (Katsu) - Skill Level: -0.7327329679254447
# Charles (Rhinar) - Skill Level: 1.4010087632715142
# Martha (Azalea) - Skill Level: 3.168221331854806
# Laura (Rhinar) - Skill Level: -0.01117682167840754
# Brian (Rhinar) - Skill Level: -1.0235664780930487
# Clare (Iyslander) - Skill Level: 0.5020085974996212
# Sandra (Bravo) - Skill Level: 1.2598346686076256
# Debra (Katsu) - Skill Level: 1.4813146590661714
# Linda (Azalea) - Skill Level: 0.4918174868211564
# Alta (Dromai) - Skill Level: 0.2816285139450166
# Richard (Fai) - Skill Level: 0.056280134111434385
# Max (Iyslander) - Skill Level: 0.6617180675193327
# Milton (Azalea) - Skill Level: 0.17339437847456932
# Dora (Iyslander) - Skill Level: -0.7983211089621819
# Sarah (Bravo) - Skill Level: 0.5658868535011936
# Brian (Iyslander) - Skill Level: -0.43617426838254364
# Jeff (Boltyn) - Skill Level: -0.2639152011850853
# Gerardo (Katsu) - Skill Level: 2.5780669707736523

# %% [markdown]
# ## Make a single round tournament

# %%
# instantiate a tournament and run a round
one_round_tournament = Tournament("One Round Tournament", players, tournament_win_prob_matrix)
one_round_tournament.simulate_tournament(1)

# print("Round Pairings and results")
# one_round_tournament.display_results()

print("\n\nTop 8 after round 1:")
one_round_tournament.get_top_n(8)
# Out:
# Top 8 after round 1:
# [Aiko (Azalea) - Skill Level: 1.2142178656850413,
#  Chastity (Azalea) - Skill Level: -0.49827447378950707,
#  Robbie (Katsu) - Skill Level: 0.16653017553799956,
#  Bernice (Katsu) - Skill Level: 0.7180935060471197,
#  Patricia (Dromai) - Skill Level: -0.14896145044912654,
#  Robert (Katsu) - Skill Level: 1.6424828356079653,
#  Conrad (Dromai) - Skill Level: 1.1444073618887027,
#  Jose (Azalea) - Skill Level: -1.0095556045166927]

# %% [markdown]
# # Running a 9 round tournament

# %%
# instantiate a 9 round tournament and run it
tournament_example = Tournament("9-round tournament", players, tournament_win_prob_matrix)
tournament_example.simulate_tournament(9)

# print("Round Pairings and results")
# tournament_example.display_results()

# print("\n\nStandings:")
# tournament_example.display_standings()

print(f"Top 8:")
for player in tournament_example.get_top_n(8):
    wins, losses = player.get_tournament_standing(tournament_example)
    print(f"{player}: {wins}-{losses}")
# Out:
# Top 8:
# Ruth (Boltyn) - Skill Level: 0.4003966995629445: 9-0
# Charles (Iyslander) - Skill Level: 1.2992535695425556: 8-1
# Britney (Boltyn) - Skill Level: 0.6111698741330147: 8-1
# Elizabeth (Dromai) - Skill Level: 0.09360488663478356: 8-1
# Donald (Bravo) - Skill Level: 0.0690242493704483: 8-1
# Maria (Fai) - Skill Level: -0.635660857812095: 8-1
# Nancy (Dromai) - Skill Level: 1.6638180472421376: 8-1
# Benjamin (Iyslander) - Skill Level: 1.0688487844369845: 8-1

# %% [markdown]
# # Doing analysis on a 1k Run

# %%
import pickle

# Load pickled list of completed tournaments
with open("completed_tournaments.pkl", "rb")as f:
    completed_tournaments = pickle.load(f)

print(f"Total tournaments: {len(completed_tournaments)}")
# Out:
# ---------------------------------------------------------------------------
# EOFError                                  Traceback (most recent call last)
# d:\Projects\Notebooks\swiss_simulator\swiss_calculator.ipynb Cell 14 line 5
#       <a href='vscode-notebook-cell:/d%3A/Projects/Notebooks/swiss_simulator/swiss_calculator.ipynb#X15sZmlsZQ%3D%3D?line=2'>3</a> # Load pickled list of completed tournaments
#       <a href='vscode-notebook-cell:/d%3A/Projects/Notebooks/swiss_simulator/swiss_calculator.ipynb#X15sZmlsZQ%3D%3D?line=3'>4</a> with open("completed_tournaments.pkl", "rb")as f:
# ----> <a href='vscode-notebook-cell:/d%3A/Projects/Notebooks/swiss_simulator/swiss_calculator.ipynb#X15sZmlsZQ%3D%3D?line=4'>5</a>     completed_tournaments = pickle.load(f)
#       <a href='vscode-notebook-cell:/d%3A/Projects/Notebooks/swiss_simulator/swiss_calculator.ipynb#X15sZmlsZQ%3D%3D?line=6'>7</a> print(f"Total tournaments: {len(completed_tournaments)}")
#
# EOFError: Ran out of input

# %%
# Utility function to find the player with the most Top 8 finishes
def find_most_top_8s(tournament_list):
    """
    Find the player with the most Top 8 finishes across all tournaments.
    
    Parameters:
    tournament_list (list): A list of Tournament objects.
    
    Returns:
    str: The alias of the player with the most Top 8 finishes.
    """
    top_8_counts = {}  # Dictionary to store the number of Top 8 finishes for each player
    for tournament in tournament_list:
        top_8_players = tournament.get_top_n(8)
        for player in top_8_players:
            if player.id in top_8_counts:
                top_8_counts[player.id] += 1
            else:
                top_8_counts[player.id] = 1

    # Find the player with the most Top 8 finishes
    most_top_8s_player = max(top_8_counts, key=top_8_counts.get)
    return most_top_8s_player, top_8_counts

# Utility function to create a DataFrame with results for every player
def create_results_dataframe(tournament_list):
    """
    Create a DataFrame with the number of Top 8 finishes for each player across all tournaments.
    
    Parameters:
    tournament_list (list): A list of Tournament objects.
    
    Returns:
    DataFrame: A DataFrame showing the number of Top 8 finishes for each player.
    """
    _, top_8_counts = find_most_top_8s(tournament_list)
    df = pd.DataFrame(list(top_8_counts.items()), columns=['Player', 'Top 8 Finishes'])
    return df.sort_values('Top 8 Finishes', ascending=False)

# %%
completed_tournaments[0].players[88].history
# Out:
# [['Tournament #0', 1, 'Melissa', 'W'],
#  ['Tournament #0', 2, 'Margarita', 'W'],
#  ['Tournament #0', 3, 'Lesa', 'W'],
#  ['Tournament #0', 4, 'Eileen', 'W'],
#  ['Tournament #0', 5, 'Adela', 'L'],
#  ['Tournament #0', 6, 'Annie', 'W'],
#  ['Tournament #0', 7, 'Eileen', 'W'],
#  ['Tournament #0', 8, 'Adela', 'L'],
#  ['Tournament #0', 9, 'Geneva', 'W']]

# %%
# getting statistics
most_top_8s_player, _ = find_most_top_8s(completed_tournaments)
print(f"The player with the most Top 8 finishes is {most_top_8s_player}")

df = create_results_dataframe(completed_tournaments)
print("DataFrame of Top 8 finishes for each player:")
df
# Out:
# The player with the most Top 8 finishes is 88
# DataFrame of Top 8 finishes for each player:
#      Player  Top 8 Finishes
# 35       88             131
# 80      254             125
# 21      351             121
# 1        17             102
# 7       343              99
# ..      ...             ...
# 426     498               1
# 428     164               1
# 429     243               1
# 225     438               1
# 354      21               1
#
# [458 rows x 2 columns]
